# %% [markdown]
# <a href="https://colab.research.google.com/github/Laiba-Gul/Beginner_python-/blob/main/Beginner_python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
xx= 2
xx= xx+4
print(xx)

yy=440-30
print(yy)

zz= yy/10
print(zz)

jj=2**xx**2
print(jj)

kk=jj%100
print(kk)
# Out:
# 6
# 410
# 41.0
# 68719476736
# 36

# %%
## Types

d=1.6
type(d)
e="1.6"
type(e)
# Out:
# str

# %%
nam=input('who are you?')
print ('welcome', nam)
# Out:
# who are you?laiba
# welcome laiba

# %%
nam=input(who are you?)
print('welcome', nam)
# Out:
#   File "/tmp/ipykernel_79587/1464417648.py", line 1
#     nam=input(who are you?)
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
inp= input("european floor?")
nsl= int(inp)+1
print ("usa floor", str(nsl))
# Out:
# european floor?1
# usa floor 2

# %%
##Exercise 2
inp=input("Enter your name:")
print("Hello", inp)
# Out:
# Enter your name:Laiba
# Hello Laiba

# %%
## Exercise 3
hours_str = input('Enter Hours')
rate_str = input('Enter Rate')
pay = hours * rate
print('Pay', pay)
# Out:
# Enter Hours35
# Enter Rate2.75
# Pay 96.25

# %%
##Assume that we execute the following assignment statements:

width = 17
height = 12.0

print(width//2)
type (width//2)
# Out:
# 8
# int

# %%
print(width/2.0)
type (width/2.0)
# Out:
# 8.5
# float

# %%
print(height/3)
type (height/3)
# Out:
# 4.0
# float

# %%
print(1 + 2 * 5)
type(1 + 2 * 5)
# Out:
# 11
# int

# %%
##Exercise 5: Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

Celsius= input('Enter the temp in Celsius')
Fahrenheit = (float(Celsius)*9/5)+32
print('Temp in Fahrenheit', Fahrenheit)
# Out:
# Enter the temp in Celsius45
# Temp in Fahrenheit 113.0

# %%
## new practice
10*3== 1000
# Out:
# False

# %%
10**3==1000
# Out:
# True

# %%
country= brazil
age = 30
print (country, age)
# Out:
# brazil
# 30

# %%
if age >= 18:
  print('adult')
else :
  print ('minor')
# Out:
# adult

# %%
for number in [1,2,34,56,4,7]:
  print (number)
# Out:
# 1
# 2
# 34
# 56
# 4
# 7

# %%
my_list = [1,3,4,7,54,44,23,33]
for x in my_list:
  print (x/3)
# Out:
# 0.3333333333333333
# 1.0
# 1.3333333333333333
# 2.3333333333333335
# 18.0
# 14.666666666666666
# 7.666666666666667
# 11.0

# %%
# function is chunk of code that is reused to perform same code and argument is an information of function that you give in ()
def is_adult(age):
    if age >= 18:
        print('adult')
    else:
        print('minor')

# %%
is_adult(16)
# Out:
# minor

# %%
is_adult(22)
# Out:
# adult

# %%
new_list = [23,4,32,55,10, 2, 1,0]
sorted(new_list)
# Out:
# [0, 1, 2, 4, 10, 23, 32, 55]
